":", # 715      
" ", # 716      
" ", # 717      
" ", # 718      
" ", # 719      
blanks(10),  # 720 - 729    
blanks(10),  # 730 - 739    
blanks(10),  # 740 - 749    
blanks(10),  # 750 - 759    
blanks(10),  # 760 - 769    
blanks(10),  # 770 - 779    
blanks(10),  # 780 - 789    
blanks(10),  # 790 - 799    
blanks(100), # 800 - 899     
blanks(100), # 900 - 999     
blanks(100), # 1000 - 1099     
blanks(10),  # 1100 - 1109    
blanks(10),  # 1110 - 1119    
# One only of the following
" ", # 1120     
# "Ś", # 1120     
"$", # 1121     
"" # Use to anchor the end
)
% Out:
% Morse_char_to_trinary_map =  ET IA NM    SU RW    DK GO             HV F     L  PJ             BX CY    ZQ                                           54  3        2             &  +         1                                        6= /        (              7        8  90                                                                                                                                                             ?_                                              "      .                   @        '                                                                                                                           -                            ;!     )                                               ,                      :                                                                                                                                                                                                                                                              
% ...

% %%
length(Morse_char_to_trinary_map)
% Out:
% ans =  1122

% %%
test = "abcdefghijklmnopqrstuvwxyz0123456789.,?'!/()&:;=+-_\"$@"
% Out:
% test = abcdefghijklmnopqrstuvwxyz0123456789.,?'!/()&:;=+-_"$@

% %%
test = toupper(test)
% Out:
% test = ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789.,?'!/()&:;=+-_"$@

% %%
out = dec2base(arrayfun(@(v) strfind(Morse_char_to_trinary_map, v)-1, test) .* 9 .+ 3^19, 3)
% Out:
% out =
%
% 10000000000000001200
% 10000000000000211100
% 10000000000000212100
% 10000000000000021100
% 10000000000000000100
% 10000000000000112100
% 10000000000000022100
% 10000000000000111100
% 10000000000000001100
% 10000000000000122200
% 10000000000000021200
% 10000000000000121100
% 10000000000000002200
% 10000000000000002100
% 10000000000000022200
% 10000000000000122100
% 10000000000000221200
% 10000000000000012100
% 10000000000000011100
% 10000000000000000200
% 10000000000000011200
% 10000000000000111200
% 10000000000000012200
% 10000000000000211200
% 10000000000000212200
% 10000000000000221100
% 10000000000002222200
% 10000000000001222200
% 10000000000001122200
% 10000000000001112200
% 10000000000001111200
% 10000000000001111100
% 10000000000002111100
% 10000000000002211100
% 10000000000002221100
% 10000000000002222100
% 10000000000012121200
% 10000000000022112200
% 10000000000011221100
% 10000000000012222100
% 10000000000021212200
% 10000000000002112100
% 10000000000002122100
% ...

% %%
out2 = arrayfun(@(v) strrep(strrep(strrep(regexprep(v, "10000000000[0]*", " "), "1", ". "), "2", "_ "), "0", ""), cellstr(out))
% Out:
% out2 =
% {
%   [1,1] =  . _
%   [2,1] =  _ . . .
%   [3,1] =  _ . _ .
%   [4,1] =  _ . .
%   [5,1] =  .
%   [6,1] =  . . _ .
%   [7,1] =  _ _ .
%   [8,1] =  . . . .
%   [9,1] =  . .
%   [10,1] =  . _ _ _
%   [11,1] =  _ . _
%   [12,1] =  . _ . .
%   [13,1] =  _ _
%   [14,1] =  _ .
%   [15,1] =  _ _ _
%   [16,1] =  . _ _ .
%   [17,1] =  _ _ . _
%   [18,1] =  . _ .
%   [19,1] =  . . .
%   [20,1] =  _
%   [21,1] =  . . _
%   [22,1] =  . . . _
%   [23,1] =  . _ _
%   [24,1] =  _ . . _
%   [25,1] =  _ . _ _
%   [26,1] =  _ _ . .
%   [27,1] =  _ _ _ _ _
%   [28,1] =  . _ _ _ _
%   [29,1] =  . . _ _ _
%   [30,1] =  . . . _ _
%   [31,1] =  . . . . _
%   [32,1] =  . . . . .
%   [33,1] =  _ . . . .
%   [34,1] =  _ _ . . .
%   [35,1] =  _ _ _ . .
%   [36,1] =  _ _ _ _ .
%   [37,1] =  . _ . _ . _
%   [38,1] =  _ _ . . _ _
%   [39,1] =  . . _ _ . .
%   [40,1] =  . _ _ _ _ .
%   [41,1] =  _ . _ . _ _
%   [42,1] =  _ . . _ .
%   [43,1] =  _ . _ _ .
%   [44,1] =  _ . _ _ . _
%   [45,1] =  . _ . . .
% ...

% %%
test2 = cellstr(test(:))
% Out:
% test2 =
% {
%   [1,1] = A
%   [2,1] = B
%   [3,1] = C
%   [4,1] = D
%   [5,1] = E
%   [6,1] = F
%   [7,1] = G
%   [8,1] = H
%   [9,1] = I
%   [10,1] = J
%   [11,1] = K
%   [12,1] = L
%   [13,1] = M
%   [14,1] = N
%   [15,1] = O
%   [16,1] = P
%   [17,1] = Q
%   [18,1] = R
%   [19,1] = S
%   [20,1] = T
%   [21,1] = U
%   [22,1] = V
%   [23,1] = W
%   [24,1] = X
%   [25,1] = Y
%   [26,1] = Z
%   [27,1] = 0
%   [28,1] = 1
%   [29,1] = 2
%   [30,1] = 3
%   [31,1] = 4
%   [32,1] = 5
%   [33,1] = 6
%   [34,1] = 7
%   [35,1] = 8
%   [36,1] = 9
%   [37,1] = .
%   [38,1] = ,
%   [39,1] = ?
%   [40,1] = '
%   [41,1] = !
%   [42,1] = /
%   [43,1] = (
%   [44,1] = )
%   [45,1] = &
%   [46,1] = :
%   [47,1] = ;
%   [48,1] = =
%   [49,1] = +
%   [50,1] = -
%   [51,1] = _
%   [52,1] = "
%   [53,1] = $
%   [54,1] = @
% }

% %%
strcat(test2, out2)
% Out:
% ans =
% {
%   [1,1] = A . _
%   [2,1] = B _ . . .
%   [3,1] = C _ . _ .
%   [4,1] = D _ . .
%   [5,1] = E .
%   [6,1] = F . . _ .
%   [7,1] = G _ _ .
%   [8,1] = H . . . .
%   [9,1] = I . .
%   [10,1] = J . _ _ _
%   [11,1] = K _ . _
%   [12,1] = L . _ . .
%   [13,1] = M _ _
%   [14,1] = N _ .
%   [15,1] = O _ _ _
%   [16,1] = P . _ _ .
%   [17,1] = Q _ _ . _
%   [18,1] = R . _ .
%   [19,1] = S . . .
%   [20,1] = T _
%   [21,1] = U . . _
%   [22,1] = V . . . _
%   [23,1] = W . _ _
%   [24,1] = X _ . . _
%   [25,1] = Y _ . _ _
%   [26,1] = Z _ _ . .
%   [27,1] = 0 _ _ _ _ _
%   [28,1] = 1 . _ _ _ _
%   [29,1] = 2 . . _ _ _
%   [30,1] = 3 . . . _ _
%   [31,1] = 4 . . . . _
%   [32,1] = 5 . . . . .
%   [33,1] = 6 _ . . . .
%   [34,1] = 7 _ _ . . .
%   [35,1] = 8 _ _ _ . .
%   [36,1] = 9 _ _ _ _ .
%   [37,1] = . . _ . _ . _
%   [38,1] = , _ _ . . _ _
%   [39,1] = ? . . _ _ . .
%   [40,1] = ' . _ _ _ _ .
%   [41,1] = ! _ . _ . _ _
%   [42,1] = / _ . . _ .
%   [43,1] = ( _ . _ _ .
% ...
